# %% [markdown]
# - Odion Joel Okonofua - johnjoel066@gmail.com - FE/23/88847286

# %% [markdown]
# # Student Progress Tracker with Insights and Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Collect User Input
def get_student_data():
    print("Welcome to the Enhanced Student Progress Tracker!")
    student_name = input("Enter the student's name: ")
    course_name = input("Enter the course name: ")
    total_modules = int(input("Enter the total number of modules in the course: "))
    completed_modules = int(input("Enter the number of modules completed: "))
    
    time_spent = []
    print("Enter time spent (in hours) for each completed module:")
    for i in range(completed_modules):
        time = float(input(f"Module {i+1}: "))
        time_spent.append(time)
    
    return student_name, course_name, total_modules, completed_modules, time_spent

# Step 2: Calculate Insights and Determine Pass Status
def calculate_insights(total_modules, completed_modules, time_spent, avg_time_per_module=5):
    progress_percentage = (completed_modules / total_modules) * 100
    avg_time_actual = sum(time_spent) / completed_modules if completed_modules > 0 else 0
    
    strengths = []
    weaknesses = []
    passed_modules = 0
    
    for i, time in enumerate(time_spent):
        if time >= avg_time_per_module:
            strengths.append((f"Module {i+1}", time))
            passed_modules += 1
        else:
            weaknesses.append((f"Module {i+1}", time))
    
    # Pass Criteria
    passed_completion = progress_percentage >= 50
    passed_time = passed_modules >= (completed_modules / 2)
    passed = passed_completion and passed_time

    return progress_percentage, avg_time_actual, strengths, weaknesses, passed

# Step 3: Display Insights and Pass/Fail Outcome
def display_insights(student_name, course_name, progress_percentage, avg_time_actual, strengths, weaknesses, passed):
    print("\n=== Progress and Insights Report ===")
    print(f"Student: {student_name}")
    print(f"Course: {course_name}")
    print(f"Progress: {progress_percentage:.2f}% completed")
    print(f"Average Time Spent per Module: {avg_time_actual:.2f} hours")
    
    print("\nStrengths (Modules where the student excelled):")
    for module, time in strengths:
        print(f"  - {module}: {time:.2f} hours")
    
    print("\nWeaknesses (Modules where the student struggled):")
    for module, time in weaknesses:
        print(f"  - {module}: {time:.2f} hours")
    
    # Pass or Fail Message
    if passed:
        print("\nCongratulations! You have passed the course requirements. 🎉")
    else:
        print("\nYou did not meet the course requirements. Keep trying and you'll succeed next time!")

# Step 4: Visualize Insights with a Beautified Chart
def visualize_insights(time_spent, avg_time_per_module):
    modules = [f"Module {i+1}" for i in range(len(time_spent))]
    expected_time = [avg_time_per_module] * len(time_spent)
    
    fig, ax = plt.subplots(figsize=(10, 5))

    # Bar Chart Comparing Actual vs Expected Time
    bars = ax.bar(modules, time_spent, label='Actual Time Spent', color=plt.cm.viridis(np.linspace(0, 1, len(time_spent))), alpha=0.8)

    # Plotting the expected time line
    ax.plot(modules, expected_time, label='Expected Time (Model)', color='#FF6347', linestyle='--', linewidth=3)

    # Adding text annotations to the bars
    for i, bar in enumerate(bars):
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval + 0.2, f'{yval:.2f}h', ha='center', va='bottom', fontsize=10, color='black')

    # Customize labels and title
    ax.set_xlabel("Modules", fontsize=14, fontweight='bold', family='Arial')
    ax.set_ylabel("Time Spent (hours)", fontsize=14, fontweight='bold', family='Arial')
    ax.set_title("Student Performance: Actual vs Expected Time", fontsize=16, fontweight='bold', family='Arial')
    
    # Adding gridlines for better readability
    ax.grid(True, axis='y', linestyle='--', alpha=0.5)
    
    # Adding a legend
    ax.legend(fontsize=12)
    
    # Adjust layout to avoid overlap
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.tight_layout()
    
    # Show the plot
    plt.show()

# Main function to run the program
def main():
    student_name, course_name, total_modules, completed_modules, time_spent = get_student_data()
    progress_percentage, avg_time_actual, strengths, weaknesses, passed = calculate_insights(
        total_modules, completed_modules, time_spent
    )
    display_insights(student_name, course_name, progress_percentage, avg_time_actual, strengths, weaknesses, passed)
    visualize_insights(time_spent, avg_time_per_module=5)

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Welcome to the Enhanced Student Progress Tracker!
# Enter the student's name:  jeol
# Enter the course name:  data science
# Enter the total number of modules in the course:  11
# Enter the number of modules completed:  9
# Enter time spent (in hours) for each completed module:
# Module 1:  5
# Module 2:  5
# Module 3:  6
# Module 4:  7
# Module 5:  6
# Module 6:  2
# Module 7:  3
# Module 8:  3
# Module 9:  4
# === Progress and Insights Report ===
# Student: jeol
# Course: data science
# Progress: 81.82% completed
# Average Time Spent per Module: 4.56 hours
#
# Strengths (Modules where the student excelled):
#   - Module 1: 5.00 hours
#   - Module 2: 5.00 hours
#   - Module 3: 6.00 hours
#   - Module 4: 7.00 hours
#   - Module 5: 6.00 hours
#
# Weaknesses (Modules where the student struggled):
#   - Module 6: 2.00 hours
#   - Module 7: 3.00 hours
#   - Module 8: 3.00 hours
#   - Module 9: 4.00 hours
#
# Congratulations! You have passed the course requirements. 🎉

# %% [markdown]
# # Course-Specific Interview Preparation Assistant

# %%
import random

# Define job roles and corresponding interview questions for each course
course_interviews = {
    "AI / Machine Learning": [
        "What is the difference between supervised and unsupervised learning?",
        "Explain overfitting and underfitting in machine learning.",
        "How do you evaluate the performance of a machine learning model?",
    ],
    "Animation": [
        "Can you explain the key principles of animation?",
        "What software are you most comfortable using for animation?",
        "How do you handle deadlines and creativity in animation projects?",
    ],
    "Cloud Computing": [
        "What is the difference between IaaS, PaaS, and SaaS?",
        "Explain cloud security and how to mitigate risks.",
        "How do you manage and monitor cloud-based infrastructure?",
    ],
    "UI/UX Design": [
        "What is the difference between UI and UX design?",
        "Can you explain the process of user-centered design?",
        "How do you gather user feedback during the design process?",
    ],
    "Data Analysis & Visualization": [
        "What tools do you use for data visualization?",
        "How do you handle missing data in a dataset?",
        "What is your experience with statistical analysis and hypothesis testing?",
    ],
    "Data Science": [
        "Can you explain the difference between data analysis and data science?",
        "What is your experience with machine learning algorithms?",
        "How do you handle large datasets and perform feature engineering?",
    ],
    "DevOps": [
        "Explain the concept of Continuous Integration/Continuous Deployment (CI/CD).",
        "How do you automate the deployment of applications in a DevOps environment?",
        "What tools have you used for configuration management?",
    ],
    "Game Development": [
        "What is your experience with game engines like Unity or Unreal Engine?",
        "How do you optimize the performance of a game?",
        "Explain the importance of storytelling in game development.",
    ],
    "Product Management": [
        "How do you prioritize features in a product roadmap?",
        "Can you describe a time when you had to make a tough product decision?",
        "How do you handle cross-functional team collaboration in product development?",
    ],
    "Quality Assurance": [
        "What is the difference between functional and non-functional testing?",
        "How do you approach writing test cases for a new product?",
        "Can you explain your experience with automated testing tools?",
    ],
    "Software Development": [
        "What programming languages are you proficient in?",
        "How do you ensure your code is scalable and maintainable?",
        "Can you describe the software development lifecycle you follow?",
    ],
    "Cybersecurity": [
        "What is your experience with penetration testing?",
        "Can you explain the importance of network security protocols?",
        "How do you handle data breaches and vulnerabilities?",
    ]
}

# Function to evaluate the user's answer based on broader keywords (expanded example)
def evaluate_answer(answer, question):
    # Expanded keywords for each course
    keywords = {
        "AI / Machine Learning": ["supervised", "unsupervised", "algorithms", "data", "training", "model", "evaluation", "prediction", "overfitting", "underfitting", "classification", "regression", "neural networks", "bias", "validation", "cross-validation", "features", "accuracy", "precision", "recall"],
        "Animation": ["principles", "software", "creativity", "deadline", "techniques", "animation", "storyboard", "motion", "3D", "2D", "visual storytelling", "rendering", "character design", "lighting", "composition"],
        "Cloud Computing": ["IaaS", "PaaS", "SaaS", "cloud security", "mitigate risks", "scalability", "network", "infrastructure", "cloud services", "monitoring", "cloud architecture", "virtualization", "resource allocation", "multicloud", "containerization"],
        "UI/UX Design": ["UI", "UX", "user-centered design", "feedback", "user research", "prototyping", "wireframing", "interaction", "usability", "accessibility", "personas", "user flows", "design systems", "A/B testing", "user interface", "user experience"],
        "Data Analysis & Visualization": ["data visualization", "missing data", "statistical analysis", "hypothesis testing", "tools", "charts", "graphs", "insights", "trends", "pivot tables", "Excel", "Power BI", "Tableau", "data cleaning", "data manipulation", "EDA", "descriptive statistics"],
        "Data Science": ["data science", "machine learning", "feature engineering", "statistical analysis", "data manipulation", "data cleaning", "regression", "classification", "prediction", "data modeling", "clustering", "outliers", "dimensionality reduction", "time series", "neural networks"],
        "DevOps": ["CI/CD", "deployment", "automation", "configuration management", "DevOps tools", "continuous integration", "cloud infrastructure", "monitoring", "containerization", "Docker", "Kubernetes", "version control", "pipelines", "scalability", "microservices", "serverless"],
        "Game Development": ["game engines", "performance", "optimization", "storytelling", "Unity", "Unreal Engine", "game design", "development", "graphics", "game mechanics", "multiplayer", "level design", "game testing", "AI in games", "user interaction"],
        "Product Management": ["product roadmap", "prioritization", "features", "decisions", "collaboration", "teamwork", "stakeholders", "planning", "vision", "requirements gathering", "agile", "scrum", "product launch", "MVP", "product lifecycle", "KPIs"],
        "Quality Assurance": ["testing", "functional", "non-functional", "automated testing", "test cases", "quality control", "debugging", "tools", "regression testing", "performance testing", "test automation", "manual testing", "bug tracking", "integration testing", "unit testing"],
        "Software Development": ["programming languages", "code", "scalability", "maintainability", "lifecycle", "software engineering", "development", "architecture", "design patterns", "debugging", "version control", "Agile", "SCRUM", "test-driven development", "frameworks", "APIs"],
        "Cybersecurity": ["penetration testing", "network security", "protocols", "breaches", "vulnerabilities", "data protection", "firewall", "threats", "encryption", "ethical hacking", "incident response", "security audit", "malware", "firewall", "zero-day", "access control"]
    }
    
    # Evaluate answer based on broader keywords
    relevant_keywords = keywords.get(question, [])
    answer_lower = answer.lower()
    matches = sum(1 for word in relevant_keywords if word.lower() in answer_lower)
    
    if matches > 4:
        return "Great job! Your answer covers the key concepts."
    elif matches > 2:
        return "Your answer is decent, but you could mention a few more important concepts."
    else:
        return "Your answer could be more comprehensive. Try including key concepts related to the topic."

# Main function to drive the app
def interview_preparation():
    # User selects the course they are preparing for
    print("Select your course:")
    for i, course in enumerate(course_interviews, 1):
        print(f"{i}. {course}")
    
    try:
        choice = int(input("Enter the number of your choice: "))
        selected_course = list(course_interviews.keys())[choice - 1]
    except (ValueError, IndexError):
        print("Invalid choice, please try again.")
        return
    
    print(f"\nYou selected: {selected_course}")
    
    # Randomly select a question for the selected course
    question = random.choice(course_interviews[selected_course])
    print(f"Interview Question: {question}")
    
    # User answers the question
    answer = input("\nYour Answer: ")
    
    # Evaluate the answer based on broader keywords
    feedback = evaluate_answer(answer, selected_course)
    print("\nFeedback:", feedback)
    
    # Additional interview tips
    print("\nInterview Tip: When answering questions, try to provide examples from your past experiences. Explain situations where you've faced challenges, how you approached solving them, and the outcome. This helps demonstrate your problem-solving skills and shows that you're capable of applying your knowledge in real-world scenarios. Remember to be confident and show your passion for the course you're applying for!")

# Run the program
if __name__ == "__main__":
    interview_preparation()
# Out:
# Select your course:
# 1. AI / Machine Learning
# 2. Animation
# 3. Cloud Computing
# 4. UI/UX Design
# 5. Data Analysis & Visualization
# 6. Data Science
# 7. DevOps
# 8. Game Development
# 9. Product Management
# 10. Quality Assurance
# 11. Software Development
# 12. Cybersecurity
# Enter the number of your choice:  6
# You selected: Data Science
# Interview Question: How do you handle large datasets and perform feature engineering?
# Your Answer:   Performed data cleaning, managed outliers, and conducted feature engineering like scaling and encoding.
# Feedback: Your answer is decent, but you could mention a few more important concepts.
#
# ...

# %% [markdown]
# Difference between Data Analysis and Data Science:
#
# Data Science: Involves machine learning, data modeling, prediction, regression, and classification.
# Data Analysis: Focuses on statistical analysis, data manipulation, and identifying trends.
#
#
# Experience with Machine Learning Algorithms:
#
# Used algorithms for regression, classification, clustering, and time series predictions.
# Worked with neural networks and dimensionality reduction techniques.
#
#
# Handling Large Datasets and Feature Engineering:
#
# Performed data cleaning, managed outliers, and conducted feature engineering like scaling and encoding.
# Utilized tools for dimensionality reduction and processed large data with optimized data manipulation techniques.
